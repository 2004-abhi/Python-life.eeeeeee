# %%
# PYTHON FUNCTIONS – PRACTICE QUESTIONS

# 1. SIMPLE POSITIONAL ARGUMENTS – 20 QUESTIONS



# 1. Create a function `student()` that accepts one positional argument
# `name` and prints the name.
def student(name):
    print("Name:", name)

student("Abhinand")
# Out:
# Name: Abhinand

# %%
# 2. Create a function `city()` that accepts one positional argument
# and prints the city.
def city(name):
    print("City:", name)

city("Kochi")
# Out:
# City: Kochi

# %%
# 3. Create a function `course()` that accepts one positional argument
# and prints the course name.

def course(name):
    print("Course:", name)

course("Python Full Stack")
# Out:
# Course: Python Full Stack

# %%
# 4. Create a function `greet()` that accepts two positional arguments
# `name` and `city` and prints both.
def greet(name, city):
    print("Name:", name)
    print("City:", city)

greet("Abhinand", "Kochi")
# Out:
# Name: Abhinand
# City: Kochi

# %%
# 5. Create a function `student()` that accepts two positional arguments
# `name` and `course` and prints both.
def student(name, course):
    print("Name:", name)
    print("Course:", course)

student("Abhinand", "Python Full Stack")
# Out:
# Name: Abhinand
# Course: Python Full Stack

# %%
# 6. Create a function `employee()` that accepts two positional arguments
# `name` and `department` and prints both.
def employee(name, department):
    print("Name:", name)
    print("Department:", department)

employee("Abhinand", "IT")
# Out:
# Name: Abhinand
# Department: IT

# %%
# 7. Create a function `college()` that accepts three positional arguments
# `name`, `course`, and `city` and prints all three.
def college(name, course, city):
    print("Name:", name)
    print("Course:", course)
    print("City:", city)

college("Abhinand", "B.Tech CSE", "Kayamkulam")
# Out:
# Name: Abhinand
# Course: B.Tech CSE
# City: Kayamkulam

# %%
# 8. Create a function `person()` that accepts three positional arguments
# `name`, `age`, and `city` and prints all three.
def person(name, age, city):
    print("Name:", name)
    print("Age:", age)
    print("City:", city)

person("Abhinand", 22, "Kochi")
# Out:
# Name: Abhinand
# Age: 22
# City: Kochi

# %%
# 9. Create a function `mobile()` that accepts one positional argument
# and prints the mobile number.
def mobile(number):
    print("Mobile Number:", number)

mobile("9876543210")
# Out:
# Mobile Number: 9876543210

# %%
# 10. Create a function `company()` that accepts two positional arguments
# `name` and `location` and prints both.
def company(name, location):
    print("Name:", name)
    print("Location:", location)

company("TCS", "Kochi")
# Out:
# Name: TCS
# Location: Kochi

# %%
# 11. Create a function `book()` that accepts two positional arguments
# `title` and `author` and prints both.
def book(title, author):
    print("Title:", title)
    print("Author:", author)

book("Wings of Fire", "A.P.J. Abdul Kalam")
# Out:
# Title: Wings of Fire
# Author: A.P.J. Abdul Kalam

# %%
# 12. Create a function `teacher()` that accepts three positional arguments
# `name`, `subject`, and `city` and prints all three.
def teacher(name, subject, city):
    print("Name:", name)
    print("Subject:", subject)
    print("City:", city)

teacher("Rahul", "Python", "Kochi")
# Out:
# Name: Rahul
# Subject: Python
# City: Kochi

# %%
# 13. Create a function `food()` that accepts two positional arguments
# `name` and `type` and prints both.
def food(name, type):
    print("Name:", name)
    print("Type:", type)

food("Pizza", "Fast Food")
# Out:
# Name: Pizza
# Type: Fast Food

# %%
# 14. Create a function `movie()` that accepts two positional arguments
# `name` and `language` and prints both.
def movie(name, language):
    print("Name:", name)
    print("Language:", language)

movie("Vikram", "Tamil")
# Out:
# Name: Vikram
# Language: Tamil

# %%
# 15. Create a function `laptop()` that accepts two positional arguments
# `brand` and `model` and prints both.
def laptop(brand, model):
    print("Brand:", brand)
    print("Model:", model)

laptop("Lenovo", "LOQ")
# Out:
# Brand: Lenovo
# Model: LOQ

# %%
# 16. Create a function `address()` that accepts three positional arguments
# `house`, `city`, and `state` and prints all three.
def address(house, city, state):
    print("House:", house)
    print("City:", city)
    print("State:", state)

address("abyy vibee", "Kochi", "Kerala")
# Out:
# House: abyy vibee
# City: Kochi
# State: Kerala

# %%
# 17. Create a function `job()` that accepts three positional arguments
# `role`, `company`, and `location` and prints all three.
def job(role, company, location):
    print("Role:", role)
    print("Company:", company)
    print("Location:", location)

job("Software Developer", "TCS", "Kochi")
# Out:
# Role: Software Developer
# Company: TCS
# Location: Kochi

# %%
# 18. Create a function `college_student()` that accepts four positional
# arguments and prints all four.
def college_student(name, course, city, age):
    print("Name:", name)
    print("Course:", course)
    print("City:", city)
    print("Age:", age)

college_student("Abhinand", "B.Tech CSE", "Kochi", 22)
# Out:
# Name: Abhinand
# Course: B.Tech CSE
# City: Kochi
# Age: 22

# %%
# 19. Create a function `profile()` that accepts four positional arguments
# `name`, `city`, `course`, and `college` and prints all four.
def profile(name, city, course, college):
    print("Name:", name)
    print("City:", city)
    print("Course:", course)
    print("College:", college)

profile("Abhinand", "Kochi", "B.Tech CSE", "Mahaguru Institute of Technology")
# Out:
# Name: Abhinand
# City: Kochi
# Course: B.Tech CSE
# College: Mahaguru Institute of Technology

# %%
# 20. Create a function `details()` that accepts five positional arguments
# and prints all five.
def details(name, age, city, course, college):
    print("Name:", name)
    print("Age:", age)
    print("City:", city)
    print("Course:", course)
    print("College:", college)

details("Abhinand", 22, "Kochi", "B.Tech CSE", "Mahaguru Institute of Technology")
# Out:
# Name: Abhinand
# Age: 22
# City: Kochi
# Course: B.Tech CSE
# College: Mahaguru Institute of Technology

# %%
#  2. DEFAULT ARGUMENTS – 20 QUESTIONS

# 21. Create a function `greet()` with a default argument `name="Student"`.
# Print the name.
def greet(name="Student"):
    print("Name:", name)

greet()
# Out:
# Name: Student

# %%
# 22. Create a function `city()` with a default argument `city="Kochi"`.
# Print the city.
def city(city="Kochi"):
    print("City:", city)

city()
# Out:
# City: Kochi

# %%
# 23. Create a function `course()` with a default argument
# `course="Python"`. Print the course.
def course(course="Python"):
    print("Course:", course)

course()
# Out:
# Course: Python

# %%
# 24. Create a function `student()` with a default argument
# `name="Arun"`. Print the name.
def student(name="Arun"):
    print("Name:", name)

student()
# Out:
# Name: Arun

# %%
# 25. Create a function `employee()` with a default argument
# `department="IT"`. Print the department.
def employee(department="IT"):
    print("Department:", department)

employee()
# Out:
# Department: IT

# %%
# 26. Create a function `college()` with a default argument
# `city="Kochi"`. Print the city.
def college(city="Kochi"):
    print("City:", city)

college()
# Out:
# City: Kochi

# %%
# 27. Create a function `teacher()` with two default arguments
# `name="Anu"` and `subject="Python"`. Print both.
def teacher(name="Anu", subject="Python"):
    print("Name:", name)
    print("Subject:", subject)

teacher()
# Out:
# Name: Anu
# Subject: Python

# %%
# 28. Create a function `student()` with two default arguments
# `name="Rahul"` and `course="Data Analytics"`. Print both.
def student(name="Rahul", course="Data Analytics"):
    print("Name:", name)
    print("Course:", course)

student()
# Out:
# Name: Rahul
# Course: Data Analytics

# %%
# 29. Create a function `company()` with a default argument
# `location="Kochi"`. Print the location.
def company(location="Kochi"):
    print("Location:", location)

company()
# Out:
# Location: Kochi

# %%
# 30. Create a function `book()` with a default argument
# `author="Unknown"`. Print the author.
def book(author="Unknown"):
    print("Author:", author)

book()
# Out:
# Author: Unknown

# %%
# 31. Create a function `movie()` with a default argument
# `language="English"`. Print the language.
def movie(language="English"):
    print("Language:", language)

movie()
# Out:
# Language: English

# %%
# 32. Create a function `food()` with a default argument
# `type="Veg"`. Print the type.
def food(type="Veg"):
    print("Type:", type)

food()
# Out:
# Type: Veg

# %%
# 33. Create a function `laptop()` with a default argument
# `brand="Dell"`. Print the brand.
def laptop(brand="Dell"):
    print("Brand:", brand)

laptop()
# Out:
# Brand: Dell

# %%
# 35. Create a function `address()` with a default argument
# `state="Kerala"`. Print the state.
def address(state="Kerala"):
    print("State:", state)

address()
# Out:
# State: Kerala

# %%
# 34. Create a function `profile()` with three default arguments
# `name`, `city`, and `course`. Print all three.
def profile(name="Abhinand", city="Kochi", course="Python"):
    print("Name:", name)
    print("City:", city)
    print("Course:", course)

profile()
# Out:
# Name: Abhinand
# City: Kochi
# Course: Python

# %%
# 36. Create a function `job()` with a default argument
# `role="Developer"`. Print the role.

def job(role="Developer"):
    print("Role:", role)

job()
# Out:
# Role: Developer

# %%
# 37. Create a function `language()` with a default argument
# `name="Python"`. Print the language.
def language(name="Python"):
    print("Language:", name)

language()
# Out:
# Language: Python

# %%
# 38. Create a function `department()` with a default argument
# `name="IT"`. Print the department.
def department(name="IT"):
    print("Department:", name)

department()
# Out:
# Department: IT

# %%
# 39. Create a function `company_details()` with two default arguments
# `company="ABC"` and `city="Kochi"`. Print both.
def company_details(company="ABC", city="Kochi"):
    print("Company:", company)
    print("City:", city)

company_details()
# Out:
# Company: ABC
# City: Kochi

# %%
# 40. Create a function `student_details()` with three default arguments
# `name="Anu"`, `course="Python"`, and `city="Kochi"`.
def student_details(name="Anu", course="Python", city="Kochi"):
    print("Name:", name)
    print("Course:", course)
    print("City:", city)

student_details()
# Out:
# Name: Anu
# Course: Python
# City: Kochi

# %%
# 3. KEYWORD ARGUMENTS – 20 QUESTIONS

# %%
# 41. Create a function `student(name, city)` and call it using keyword
# arguments.
def student(name, city):
    print("Name:", name)
    print("City:", city)

student(name="Abhinand", city="Kochi")
# Out:
# Name: Abhinand
# City: Kochi

# %%
# 42. Create a function `employee(name, department)` and call it using
# keyword arguments.
def employee(name, department):
    print("Name:", name)
    print("Department:", department)

employee(name="Abhinand", department="IT")
# Out:
# Name: Abhinand
# Department: IT

# %%
# 43. Create a function `course(name, duration)` and call it using
# keyword arguments.
def course(name, duration):
    print("Course:", name)
    print("Duration:", duration)

course(name="Python", duration="6 Months")
# Out:
# Course: Python
# Duration: 6 Months

# %%
# 44. Create a function `person(name, city, age)` and call it using
# keyword arguments.
def person(name, city, age):
    print("Name:", name)
    print("City:", city)
    print("Age:", age)

person(name="Abhinand", city="Kochi", age=22)
# Out:
# Name: Abhinand
# City: Kochi
# Age: 22

# %%
# 45. Create a function `college(name, course, city)` and call it using
# keyword arguments.

def college(name, course, city):
    print("Name:", name)
    print("Course:", course)
    print("City:", city)

college(name="Abhinand", course="B.Tech CSE", city="Kochi")
# Out:
# Name: Abhinand
# Course: B.Tech CSE
# City: Kochi

# %%
# 46. Create a function `teacher(name, subject)` and call it using
# keyword arguments.
def teacher(name, subject):
    print("Name:", name)
    print("Subject:", subject)

teacher(name="Anu", subject="Python")
# Out:
# Name: Anu
# Subject: Python

# %%
# 47. Create a function `company(name, location)` and call it using
def company(name, location):
    print("Name:", name)
    print("Location:", location)

company(name="TCS", location="Kochi")
# Out:
# Name: TCS
# Location: Kochi

# %%
# 48. Create a function `book(title, author)` and call it using keyword
def book(title, author):
    print("Title:", title)
    print("Author:", author)

book(title="Wings of Fire", author="A.P.J. Abdul Kalam")
# Out:
# Title: Wings of Fire
# Author: A.P.J. Abdul Kalam

# %%
# 49. Create a function `movie(name, language)` and call it using keyword
def movie(name, language):
    print("Name:", name)
    print("Language:", language)

movie(name="Vikram", language="Tamil")
# Out:
# Name: Vikram
# Language: Tamil

# %%
# 50. Create a function `laptop(brand, model)` and call it using keyword
# arguments.

def laptop(brand, model):
    print("Brand:", brand)
    print("Model:", model)

laptop(brand="Lenovo", model="LOQ")
# Out:
# Brand: Lenovo
# Model: LOQ
