# %%
# check whether 36 is divisible by 6
if (36%6==0):
    print("36 is divisible ")
# Out:
# 36 is divisible

# %%
# check weather 7 is positive
if (7>0):
    print("7 is positive")
# Out:
# 7 is positive

# %%
# check whether 37 is not divisible 5
if (37%5!=0):
    print("37 is not divisible 5")
# Out:
# 37 is not divisible 5

# %%
if (48%8==0):
    print("48 is multiple by 8")
# Out:
# 48 is multiple by 8

# %%
if (50%7!=0):
    print("50 is not multiple by 7")
# Out:
# 50 is not multiple by 7

# %%
a=25
b=10
c=40
if((25>10) & (25<40)):
    print("25 is between 10 and 40 ")
# Out:
# 25 is between 10 and 40

# %%
a=55
b=20
c=45
if ((a>20) & (a<45)):
    print("55 is between 20 and 45")
else :
    print("55 is not in the range of 20 and 45")
# Out:
# 55 is not in the range of 20 and 45

# %%
# Check whether 80 is greater than both 35 and 60.
a=80
b=35
c=60
if ((a>35) & (a>60)):
    print("80 is greater than both 35 and 60")
# Out:
# 80 is greater than both 35 and 60

# %%
#  Check whether 12 is smaller than both 20 and 30.
a=12
b=20
c=30
if ((a<b) & (a<c)):
    print("12 is smaller than both 20 and 30")
# Out:
# 12 is smaller than both 20 and 30

# %%
# Check whether 15 is equal to either 15 or 25
a=15
b=15
c=25
if ((a==b) | (a==c)):
    print(" 15 is equal to either 15 or 25")
# Out:
#  15 is equal to either 15 or 25

# %%
#  Check whether 20 is different from both 10 and 30
a=20
b=10
c=30
if ((a!=b) & (a!=c)):
    print("20 is different from both 10 and 30")
# Out:
# 20 is different from both 10 and 30

# %%
# Check whether the sum of 8 and 14 is positive.
a=8
b=14
c=8+14

if (c>0):
    print("sum of 8 and 14 is positive")
# Out:
# sum of 8 and 14 is positive

# %%
 # Check whether the sum of 11 and 13 is even. 
a=11
b=13
c=11+13
if (c%2==0):
    print("sum of 11 and 13 is even")
# Out:
# sum of 11 and 13 is even

# %%
#  . Check whether the sum of 42 and 7 is divisible by 7.
a=42
b=7
c=42+7
if (c%7==0):
    print("sum of 42 and 7 is divisible by 7")
# Out:
# sum of 42 and 7 is divisible by 7

# %%
# Check whether the difference between 25 and 10 is positive.
a=25
b=10
c=25-10
if (c>0):
    print("difference between 25 and 10 is positive")
# Out:
# difference between 25 and 10 is positive

# %%
# Check whether the difference between 18 and 6 is even.
a=18-6
if (a%2==0):
    print("difference between 18 and 6 is even")
# Out:
# difference between 18 and 6 is even

# %%
# Check whether the product of 7 and 9 is positive.
a=7*9
if (a>0):
    print("product of 7 and 9 is positive")
# Out:
# product of 7 and 9 is positive

# %%
#  Check whether the product of 12 and -5 is negative
a=12*-5
if (a<0):
    print("product of 7 and 9 is positive")
# Out:
# product of 7 and 9 is positive

# %%
# Check whether the product of 36 and 6 is divisible by 6.
a=36
b=6
c=a*b
if (c%6==0):
    print("product of 36 and 6 is divisible by 6")
# Out:
# product of 36 and 6 is divisible by 6

# %%
#  Check whether 45 is a two-digit number.
a=45
if (a>9):
    print("whether 45 is a two-digit number")
# Out:
# whether 45 is a two-digit number

# %%
# Check whether 125 is a three-digit number.
a=125
if (a>99):
    print("whether 125 is a three-digit number")
# Out:
# whether 125 is a three-digit number

# %%
#  Check whether 150 is greater than 100
if (150>100):
    print("150 is greater than 100")
# Out:
# 150 is greater than 100

# %%
# Check whether 75 is smaller than 100
if (75<100):
    print("75 is smaller than 100")
# Out:
# 75 is smaller than 100

# %%
# Check whether 600 is greater than 500
if (600>500):
    print("600 is greater than 500")
# Out:
# 600 is greater than 500

# %%
#  Check whether 250 is smaller than 500.
if (250<500):
    print("250 is smaller than 500")
# Out:
# 250 is smaller than 500

# %%
# Check whether 72 is divisible by both 8 and 9
if ((72%8==0 ) & (72%9==0)):
    print("72 is divisible by both 8 and 9")
# Out:
# 72 is divisible by both 8 and 9

# %%
# Check whether 35 is divisible by either 6 or 7
if ((35%6==0) | (35%7==0)):
    print("35 is divisible by either 6 or 7")
# Out:
# 35 is divisible by either 6 or 7

# %%
# Check whether 25 is greater than 10 but smaller than 40.
if ((25>10) | (25<40)):
    print("25 is greater than 10 but smaller than 40")
# Out:
# 25 is greater than 10 but smaller than 40

# %%
# Check whether 15 is smaller than 30 but greater than 5
if ((15<30)|(15>5)):
    print("5 is smaller than 30 but greater than 5")
# Out:
# 5 is smaller than 30 but greater than 5
