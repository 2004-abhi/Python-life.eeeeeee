# %%
#  print number from 1 to n
n = int(input("Enter a number: "))
i=1
while i <= n :
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# find sum of numbers from 1 to n
n = int(input("Enter a number: "))
sum =0
i=1
while i <= n :
    sum=sum + i
    i=i+1
print(sum )
# Out:
# 15

# %%
# find sum of odd numbers from 1 to n
n = int(input("Enter a number: "))
sum=0
i=1
while i <= n :
    if(i%2!=0):
        sum = sum + i
    i=i+1
print(sum)
# Out:
# 9

# %%
# count how many numbers are present from 1 to n
n = int(input("Enter a number: "))
count =0
i=1
while i <= n :
    count+=1
    i+=1
print(count)
# Out:
# 7

# %%
# print multiplication table of a numbers
n = int(input("Enter a number: "))
i=1
result =1
while(i<=10):
    result=i*n
    print(i," ","X",n," = ",result)
    i+=1
# Out:
# 1   X 3  =  3
# 2   X 3  =  6
# 3   X 3  =  9
# 4   X 3  =  12
# 5   X 3  =  15
# 6   X 3  =  18
# 7   X 3  =  21
# 8   X 3  =  24
# 9   X 3  =  27
# 10   X 3  =  30

# %%
# print squares of numbers from 1 to n 1*1 2*2 3*3
n = int(input("Enter a number: "))
i=1
squar=0
while(i<=n):
    squar=i*i
    print(i,"*",i," = ",squar)
    i=i+1
# Out:
# 1 * 1  =  1
# 2 * 2  =  4
# 3 * 3  =  9
# 4 * 4  =  16

# %%
# count number of digits in a number
n = int(input("Enter a number: "))

count =0
while n != 0:
    n= n//10
    count+=1
print("Number of digits:", count)
# Out:
# Number of digits: 6

# %%
a=10
b=3
result = a / b
print(result)
print(type(result))
# Out:
# 3.3333333333333335
# <class 'float'>

# %%
a=10
b=3
result = a % b
print(result)
print(type(result))
# Out:
# 1
# <class 'int'>

# %%
n = int(input("Enter a number: "))
n_reverse=0
temp=0
while n!=0 :
    temp = n %10
    n_reverse= n_reverse*10 +temp
    n=n //10
print(n_reverse)
# Out:
# 43

# %%
# sum and product of numbers
n = int(input("Enter a number: "))
n_reverse=0
sum=0
product=1
temp=0
while n!=0 :
    temp = n %10
    n_reverse= n_reverse*10 +temp
    sum=sum+temp
    product=product*temp
    n=n //10
print(n_reverse)    
print(sum)
print(product)
# Out:
# 43
# 7
# 12

# %%
n = int(input("Enter a number: "))
n_revers=0
temp=0
sum=0
while n !=0 :
    temp=n%10
    sum = sum + temp
    n_revers=n_revers*10 +temp
    n= n // 10
if(sum % 10==1):
    print("it is a magic number")
else:
    print("it is not a magic number")
# Out:
# it is not a magic number

# %%
# print cubes of numbers from 1 to n
n = int(input("Enter a number: "))
i =1
while i <= n :
    print(i,"*",i,"*",i,"*",i*i*i)
    i=i+1
# Out:
# 1 * 1 * 1 * 1
# 2 * 2 * 2 * 8
# 3 * 3 * 3 * 27
# 4 * 4 * 4 * 64

# %%
# print number divisible by bot 3 and 5
n = int(input("Enter a number: "))
i=1
while i<=n:
    if (i%3==0 and i%5==0):
        print(i)
    i=i+1
# Out:
# 15
# 30
# 45

# %%
#
