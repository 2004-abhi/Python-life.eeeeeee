# %%
# for 360 ,check whether it is positive .if positive ,check whether it is evan. if evan ,check it is divisible by 10.if divisible by 10, check whether it is greater than 300.
a=360
if(a>0):
    if(a%2==0):
        if(a%10==0):
            if(360>300):
               print(" yes")
else:
    print(a,"is not positive")
# Out:
#  yes

# %%
if (144>0):
    print(144,"is positive")
    if (144%2==0):
        print("144 is evan ")
        if (144%4==0):
            print("144 is divisible by 4 ")
    elif(144%8==0):
        print("144 is divisible by 8 ")
    elif(144%12==0):
        print("144 is divisible by 12 ")
    else:
        print("condition is not sutable ")
# Out:
# 144 is positive
# 144 is evan
# 144 is divisible by 4

# %%
if(225>0):
    print("255 is positive ")
    if(225%2!=0):
       print("255 is odd ")
       if(225%3==0):
           print("255 is divisible by 3 ")
       elif(225%5==0):
           print("255 is divisible by 5 ")
    elif(255%15==0):
        print("255 is divisible by 15 ")
    else:
        print("condition is not satisfy ")
# Out:
# 255 is positive
# 255 is odd
# 255 is divisible by 3

# %%
if (120>0):
    print("120 is positive ")
    if(120%2==0):
        print("120 is evan ")
        if (120 < 100):
            print("120 is below 100 ")
        else:
            print("120 is above 100 ")
    elif((100<120) & (120<150)):
        print("it is between 100 and 150 ")
    elif(120 >150):
        print("120 is above 150 ")
    else:
        print("condition not satisfied ")
# Out:
# 120 is positive
# 120 is evan
# 120 is above 100

# %%
if (99>0):
    print("99 is positive ")
    if(99%2!=0):
        print(" 99 is odd")
        if(99%3==0):
            print("99 is divisible by 3 ")
            if(99%9==0):
               print("99 is divisible by 9 " )
        else:
            print("99 is evan ")
# Out:
# 99 is positive
#  99 is odd
# 99 is divisible by 3
# 99 is divisible by 9

# %%
if(180>100):
    print("180 is > 100 ")
    if (180%2==0):
        print("180 is evan ")
        if(180 % 10==0):
            print("180 is divisible by 10 ")
            if(180>150):
                print("180 > 150 ")
            else:
                print("180 is smaller 150")
        else:
            print("180 is not divisible by 10 ")
    else:
        print("180 is odd ")
# Out:
# 180 is > 100
# 180 is evan
# 180 is divisible by 10
# 180 > 150

# %%
if(72>0):
    print("72 is positive ")
    if(72%2==0):
        print("72 is evan ")
        if(72%4==0):
            print("72 divisible by 4 ")
        elif(72%8==0):
            print("72 divisible by 8 ")
        elif(72%6==0):
            print("72 divisible by 6 ")
    else:
        print("72 is odd ")   
else:
    print("72 is neative ")
# Out:
# 72 is positive
# 72 is evan
# 72 divisible by 4

# %%
if(125>0):
    print("125 is positive ")
    if(125%2!=0):
        print(" 125 is odd")
        if(125%5==0):
            print("125 is divisible by 5 ")
            if(125>100):
                print("125 > 100 ")
            else:
                print("125 < 100 ")
        else:
            print("125 is not divisible by 5 ")
    else:
        print("125 is evan ")
else:
    print("125 is neaative ")
# Out:
# 125 is positive
#  125 is odd
# 125 is divisible by 5
# 125 > 100

# %%
if(96>0):
    print("96 is positive ")
    if(96%2==0):
        print("96 is evan ")
        if((96%4==0)&(96%8==0)):
            print("96 is divisible by 4 and 8 ")
            if(96>90):
                print(" 96 is > 90")
# Out:
# 96 is positive
# 96 is evan
# 96 is divisible by 4 and 8
#  96 is > 90

# %%
if(150>0):
    print("150 is positive ")
    if(150%2==0):
        print("150 is evan ")
        if(150%5==0):
            print("150 is divisible by 5 ")
            if(100>150):
                print("150 below 100 ")
            elif((100<150)&(150<200)):
                print("150 is between 150 and 200 ")
            elif(150 >200):
                print("150 is above 200 ")
# Out:
# 150 is positive
# 150 is evan
# 150 is divisible by 5
# 150 is between 150 and 200

# %%
# 17
if(225>100):
    print("255 is > 100 ")
    if(255%2!=0):
        print("255 is odd ")
        if(255%5==0):
            print("255 is divisible by 5 ")
# Out:
# 255 is > 100
# 255 is odd
# 255 is divisible by 5
