# %%
print("started  ")   # function call statement with arguments   h  g  ""
def add(a,b):
    c=a+b
    print(c)
print("prom ended ")  
add(2,3)
# Out:
# started
# prom ended
# 5

# %%
# create following functions, greet() and print hello world
def greet():
    print("hello world")
greet()
# Out:
# hello world

# %%
# subtract(),sub two no , mul two no
def subtract(a,b):
    c=a-b
    z=a*b
    print(c)
    print(z)
subtract(20,4)
# Out:
# 16
# 80

# %%
def subtract(a, b):
    print(a - b)

def mul(a, b):
    print(a * b)

subtract(20, 4)
mul(20, 4)
# Out:
# 16
# 80

# %%
def subtract():
    a=10
    b=20
    c=a-b
    print(c)
    print(a*b)
subtract()
# Out:
# -10
# 200

# %%
# creating a function to check whether a number is even or not.
def example(i):
    if i % 2 == 0:
        print("Even")
    else:
        print("Not Even")

example(10)
# Out:
# Even

# %%
# create a function check () that checks if 10>5. if true ,print 10 is greater
def check():
    if 10 > 5:
        print("10 is greater")
    else:
        print("10 is not greater")

check()
# Out:
# 10 is greater

# %%
# create a fn number() that checks wheather 20 is evan or odd
def number(i):
    if i % 2 == 0:
        print("Even")
    else:
        print("Odd")

number(20)
# Out:
# Even

# %%
# create a fn age () that checks if 18 >=18 if true ,print eligible
def age(i):
    if i >= 18:
        print("Eligible")
    else:
        print("Not Eligible")

age(20)
# Out:
# Eligible

# %%
# create fn temparature() that checks if 35>30 if true print hot
def temperature():
    if 35 > 30:
        print("Hot")
    else:
        print("Not Hot")

temperature()
# Out:
# Hot

# %%
# create a fn marks if 75>=40 if true , print pass
def marks():
    if 75 >= 40:
        print("Pass")
    else:
        print("Fail")

marks()
# Out:
# Pass

# %%
#  create fn num( ) check wheather 100 == 100 if true , print pass
def num():
    if 100 == 100:
        print("Pass")
    else:
        print("Fail")

num()
# Out:
# Pass

# %%
#create a  fn num() that checks wheather 15<10  .if  true  ,print "15 is smaller"
def num():
    if 15 < 10:
        print("15 is smaller")
    else:
        print("15 is not smaller")

num()
# Out:
# 15 is not smaller

# %%
#create a fn check () that checks wheather 25  is divisible by 5.if true  ,print "divisible"
def check():
    if 25 % 5 == 0:
        print("Divisible")

check()
# Out:
# Divisible

# %%
# #create a  fn number () that checks wheather 50 is  greater than  25 if true ,print "greater",otherwise
def number():
    if 50 > 25:
        print("Greater")
    else:
        print("Not Greater")

number()
# Out:
# Greater

# %%
# create fn() and print hello world 5 times usin multiple fn() STATEMENTS
def fn():
    print("Hello World")

fn()
fn()
fn()
fn()
fn()
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
def greet(name):
    print("Hello", name)

greet("Abhi")
greet("Rahul")
# Out:
# Hello Abhi
# Hello Rahul

# %%
def subt(a,b):
    c=a-b
    print (c)
print( "progm started ")
subt(100,10)
# Out:
# progm started
# 90

# %%
# create a fun() called maths () pass the values and perform add sub mul div mod power
def maths(a,b):
    c=a+b
    print(c)
    d=a-b
    print(d)
    f=a*b
    print(f)
    v=a/b
    print(v)
    m=a%b
    print(m)
    z=a**b
    print(z)
print( "start execution ")
maths(2,5)
# Out:
# start execution
# 7
# -3
# 10
# 0.4
# 2
# 32

# %%
def mathss(a, b):
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")
    print("6. Power")

    choice = int(input("Enter your choice: "))

    match choice:
        case 1:
            print("Addition:", a + b)
        case 2:
            print("Subtraction:", a - b)
        case 3:
            print("Multiplication:", a * b)
        case 4:
            if b != 0:
                print("Division:", a / b)
            else:
                print("Cannot divide by zero")
        case 5:
            if b != 0:
                print("Modulus:", a % b)
            else:
                print("Cannot divide by zero")
        case 6:
            print("Power:", a ** b)
        case _:
            print("Invalid choice")


print("Start execution")

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

mathss(a, b)
# Out:
# Start execution
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# Addition: 5

# %%
# create a func call d1() and print number 1-5 using while loop
def d1(i):
    while i<5:
        i=i+1
        print(i)
d1(0)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# create a list with fun( ) and pass the values to append it to the list
mylist=[]
def fun(q):
    mylist.append(q)
fun(10)
fun(20)
fun(30)
fun(50)    
print(mylist)
# Out:
# [10, 20, 30, 50]

# %%
def fun():
    listooo=[]
    listooo.append(10)
    listooo.append(40)
    listooo.append(30)
    listooo.append(20)
    print(listooo)
fun()
# Out:
# [10, 40, 30, 20]

# %%
# create a list with in the fun() and take value from the user and append it
def fun():
    list=[]
    listt=int(input("enter limit of list "))
    for _ in range(listt):
        item=int(input("enter items "))
        list.append(item)

    print(list)
    print("ditance of list :",len(list))
    print("sum of list :",sum(list))  
    # print("sub of list : ",sub(list))
    print(" max of list :",max(list))
    print(" min of list :",min(list)) 
fun()
# Out:
# [23, 34, 45, 22]
# ditance of list : 4
# sum of list : 124
#  max of list : 45
#  min of list : 22

# %%
def fun():
    my_list = []

    limit = int(input("Enter limit of list: "))

    for _ in range(limit):
        item = int(input("Enter item: "))
        my_list.append(item)

    print("List:", my_list)
    print("Distance of list:", len(my_list))
    print("Sum of list:", sum(my_list))
    print("Max of list:", max(my_list))
    print("Min of list:", min(my_list))

fun()
# Out:
# List: [23, 34, 56, 12]
# Distance of list: 4
# Sum of list: 125
# Max of list: 56
# Min of list: 12

# %%
# crate a function sum pass 2 arguments and execute it
def sum(a,b):
    c=a+b
    print(c)
sum(10,20)   #arguments
# Out:
# 30

# %%
# create a function called "details" pass the name of the student , mark and grade .
def details(name,mark,grade):
    print( "name is : ",name )
    print( "mark is : ",mark )
    print( "grade is :",grade )
details( "abu ",50, "B+ "  )
# Out:
# name is :  abu
# mark is :  50
# grade is : B+

# %%
# create a fn called sum 3 values but recieve only two
def fn(a,b):
    result=a+b+z 
    print(result)
fn(10,20,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # create a fn called sum 3 values but recieve only two
#       2 def fn(a,b):
#       3     result=a+b+z
#       4     print(result)
# ----> 5 fn(10,20,40)
#       6
#       7
#
# TypeError: fn() takes 2 positional arguments but 3 were given

# %%
def sum(a, b, c=0):
    result = a + b + c
    print(result)

sum(10, 20)
# Out:
# 30

# %%
def add(a,b,c=5):  # c is a defalult parameter, it is already inti******************alised 
    d=a+b+c
    print(d)
add(4,2,7)
# Out:
# 13

# %%
# create a fn() name details print name , class , mark . 
def details(name, clas, mark):
    print("Name:", name)
    print("Class:", clas)
    print("Mark:", mark)

details("Abhinand", "B.Tech", 85)
# Out:
# Name: Abhinand
# Class: B.Tech
# Mark: 85

# %%
def details():
    name = input("Enter name: ")
    clas = input("Enter class: ")
    mark = int(input("Enter mark: "))

    print("Name:", name)
    print("Class:", clas)
    print("Mark:", mark)

details()
# Out:
# Name: abyyy
# Class: 12b
# Mark: 98

# %%
# call fun() called power and let default argument to be passed , pass value and find resultant of expression 
def power(a, b=2):
    c = a ** b
    print(c)

power(5)
# Out:
# 25

# %%
def power(num=2):
    print("power is : ",num ** 2)
power(6)
# Out:
# power is :  36

# %%
def power(a, b=2):
    c = a ** b
    print("Result:", c)

a = int(input("Enter base: "))
b = int(input("Enter exponent: "))

power(a, b)
# Out:
# Result: 144

# %%
# Q1. Create greet() with one positional argument name and print the name.
def greet(name):
    print(name)

greet("Abhi")
# Out:
# Abhi

# %%
# Q2. Create add() with two positional arguments and print their sum.
def add(a, b):
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
# Q3. Create student() that takes name and age and prints both.
def student(name, age):
    print("Name:", name)
    print("Age:", age)

student("Abhi", 22)
# Out:
# Name: Abhi
# Age: 22

# %%
# Q4. Create square() that takes one number and prints its square.
def square(n):
    print(n ** 2)

square(5)
# Out:
# 25

# %%
# Q5. Create multiply() that takes two positional arguments and prints their product.
def multiply(a, b):
    print(a * b)

multiply(4, 5)
# Out:
# 20

# %%
# write a fun( ) greet name = student as a default argument . call it with argument
def greet(name="student "):
    print("allo ",name)
    
greet()
# Out:
# allo  student

# %%
def country(name="india "):
    print(name)
country()
country("japan")
# Out:
# india
# japan

# %%
def age(age=18):
    print("age :",age)
age()
age(21)
# Out:
# age : 18
# age : 21

# %%
def cllg(name="abc "):
    print(name)
cllg()
cllg("snmass")
# Out:
# abc
# snmass

# %%
def power(number,power=2):
    resu=number**power
    print(resu)
power(5)
power(5,3)
# Out:
# 25
# 125

# %%
# 1 write a fn () bill (item , quantity=1) and call it wit only te item  wit item and quantity
def bill(item, quantity=1):
    print("Item:", item)
    print("Quantity:", quantity)

bill("Apple")
bill("Mango", 5)
# Out:
# Item: Apple
# Quantity: 1
# Item: Mango
# Quantity: 5

# %%
# 2 write  a fn () student (name ,age=18 ) And call it in two different ways

def student(name, age=18):
    print("Name:", name)
    print("Age:", age)

student("Abhi")
student("Rahul", 21)
# Out:
# Name: Abhi
# Age: 18
# Name: Rahul
# Age: 21

# %%
# 3 write a fn() welcome (name , message="welcome ") and call it : using only name using argument
def welcome(name , message="welcome "):
    print("Name:", name)
    print("message:", message)
welcome("abyyy ")
#   welcome("Abhi", "nee super adeyyy")
# Out:
# Name: abyyy
# message: welcome

# %%
# 4 write a fn employee (name,department="IT").call it for: "rahul"  "alan"
def employee(name, department="IT"):
    print("Name:", name)
    print("Department:", department)

employee("Rahul")
employee("Alan")
employee("hr")
# Out:
# Name: Rahul
# Department: IT
# Name: Alan
# Department: IT
# Name: hr
# Department: IT

# %%
# 5 write a fn calculate (a,b=10)that prints a+b call it with only a,then both arguments.
def calculate(a, b=10):
    print(a + b)

calculate(5)
calculate(5, 20)
# Out:
# 15
# 25

# %%
def calculate(a, b=10):
    print(a + b)

# Call with only a
calculate(5)

# Call with both arguments
calculate(5, 20)
# Out:
# 15
# 25

# %%
# 6 create a fn() phone (brand , price) and print the brand and price
def phone(brand, price):
    print("Brand:", brand)
    print("Price:", price)

phone("iQOO", 25000)
# Out:
# Brand: iQOO
# Price: 25000

# %%
# 7 create a fun()movie (name , language="english ") and print both values 
def movie(name, language="english"):
    print("Movie:", name)
    print("Language:", language)

movie("Avatar")
movie("Drishyam", "Malayalam")
# Out:
# Movie: Avatar
# Language: english
# Movie: Drishyam
# Language: Malayalam

# %%
# 8 create a fn() book (title,author="unknown ") and print title and author.
def book(title, author="unknown"):
    print("Title:", title)
    print("Author:", author)

book("Python Basics")
book("Wings of Fire", "A. P. J. Abdul Kalam")
# Out:
# Title: Python Basics
# Author: unknown
# Title: Wings of Fire
# Author: A. P. J. Abdul Kalam

# %%
# 9 create  fn() login (username,password="12345 ") and call fn()in two
def login(username, password="12345"):
    print("Username:", username)
    print("Password:", password)

# 1. Call using only username
login("Abhi")

# 2. Call using username and password
login("Rahul", "abc789")
# Out:
# Username: Abhi
# Password: 12345
# Username: Rahul
# Password: abc789

# %%
# 10 create a fn() college (name,course="BCA ") and print details
def college(name,course="BCA "):
    print("name :",name)
    print("course :",course)
college("abu ")
college("abyy ","CSE ")
# Out:
# name : abu
# course : BCA
# name : abyy
# course : CSE

# %%
# 11 create a fun() travel(place,days=2)and print the place and number of days
def travel(place, days=2):
    print("Place:", place)
    print("Number of days:", days)

# Call 1: Only place
travel("Goa")

# Call 2: Place and days
travel("Munnar", 5)
# Out:
# Place: Goa
# Number of days: 2
# Place: Munnar
# Number of days: 5

# %%
# 12 create a fn() oder (item ,quantity=1) and print oder details
def order(item, quantity=1):
    print("Item:", item)
    print("Quantity:", quantity)

order("Pizza")
order("Burger", 3)
# Out:
# Item: Pizza
# Quantity: 1
# Item: Burger
# Quantity: 3

# %%
# 13 create fn( ) exam ( subject, mark=100) and print subject and total  mark
def exam(subject, mark=100):
    print("Subject:", subject)
    print("Total mark:", mark)

exam("Python")
exam("Mathematics", 80)
# Out:
# Subject: Python
# Total mark: 100
# Subject: Mathematics
# Total mark: 80

# %%
# 14 create a fn() account (name ,balance=0 ) and print account details
def account(name, balance=0):
    print("Name:", name)
    print("Balance:", balance)

account("Abhi")
account("Rahul", 5000)
# Out:
# Name: Abhi
# Balance: 0
# Name: Rahul
# Balance: 5000

# %%
# 10
def game( name , players = 4):
    print("Game name: ",name)
    print("number of players : ",players)

game("BGMI")
# Out:
# Game name:  BGMI
# number of players :  4
